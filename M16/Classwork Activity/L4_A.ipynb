# %%
import pandas as pd #it will be used for handling the data
import numpy as np # mathematical operations (median, arrays, etc.)
import matplotlib.pyplot as plt # basic plotting graphs
import seaborn as sns #advanced statistical visualization

data = pd.read_csv('Titanic Dataset.csv') #it helps us to read the csv data

data.head(5) # top 5 rows

print(data.dtypes) #will show the data types of each columns

nominal_cat = ['Name', 'Ticket', 'Cabin'] #this is the list of nominal categories
#nominal categories have no norder
ordinal_cat = ['Embarked', 'Gender']
#ordinal categories have logical order
data['Gender'].value_counts()# it helps us to count the totla number of female and male

gender_categories = ['Female', 'Male'] #two categories for the gender male and female

data['Gender'] = pd.Categorical(data['Gender'], gender_categories, ordered = True)#converts g ender column into categorical

median_index = np.median(data["Gender"].cat.codes)#converts female -> 0 and male -> 1
median_gender = gender_categories[int(median_index)]#converts median index back to categorical

print(median_gender)

data['Embarked'].value_counts() # shows how many pessenger boarded from s--> Southampton, c--> Cherbourg, Q--> Queenstown

embarked_categories = ['S', 'C', 'Q'] #mentioning the embarked categorical

data['Embarked'] = pd.Categorical(data['Embarked'], embarked_categories, ordered = True)# boarding location have ordered

median_index = np.median(data['Embarked'].cat.codes) #convert categories to numbers find median
median_embarked = embarked_categories[int(median_index)] #convert back to category

print(median_embarked) 

data.head(5)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Gender          object
# dtype: object
# Male
# S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
# ...
