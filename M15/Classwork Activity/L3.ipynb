# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
countries_df = pd.read_csv('Countries Data.csv')
countries = countries_df
countries.head(3)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952   8425333.0      Asia    28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia    30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia    31.997  853.100710

# %%
c_52 = countries.loc[countries['year'] == 1952]
c_52.head()
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952   8425333.0      Asia    28.801   779.445314
# 12      Albania  1952   1282697.0    Europe    55.230  1601.056136
# 24      Algeria  1952   9279525.0    Africa    43.077  2449.008185
# 36       Angola  1952   4232095.0    Africa    30.015  3520.610273
# 48    Argentina  1952  17876956.0  Americas    62.485  5911.315053

# %%
c_07 = countries.loc[countries['year'] == 2007]
c_07.head()
# Out:
#         country  year  population continent  life_exp       gdp_cap
# 11  Afghanistan  2007  31889923.0      Asia    43.828    974.580338
# 23      Albania  2007   3600523.0    Europe    76.423   5937.029526
# 35      Algeria  2007  33333216.0    Africa    72.301   6223.367465
# 47       Angola  2007  12420476.0    Africa    42.731   4797.231267
# 59    Argentina  2007  40301927.0  Americas    75.320  12779.379640

# %%
type(c_52)
# Out:
# pandas.core.frame.DataFrame

# %%
c_merge = pd.merge(c_52, c_07, left_on='country', right_on='country')

# %%
c_merge.head()
# Out:
#        country  year_x  population_x continent_x  life_exp_x    gdp_cap_x  \
# 0  Afghanistan    1952     8425333.0        Asia      28.801   779.445314
# 1      Albania    1952     1282697.0      Europe      55.230  1601.056136
# 2      Algeria    1952     9279525.0      Africa      43.077  2449.008185
# 3       Angola    1952     4232095.0      Africa      30.015  3520.610273
# 4    Argentina    1952    17876956.0    Americas      62.485  5911.315053
#
#    year_y  population_y continent_y  life_exp_y     gdp_cap_y
# 0    2007    31889923.0        Asia      43.828    974.580338
# 1    2007     3600523.0      Europe      76.423   5937.029526
# 2    2007    33333216.0      Africa      72.301   6223.367465
# 3    2007    12420476.0      Africa      42.731   4797.231267
# 4    2007    40301927.0    Americas      75.320  12779.379640

# %%
c_merge.drop(['year_x', 'year_y'], axis=1)
# Out:
#                 country  population_x continent_x  life_exp_x    gdp_cap_x  \
# 0           Afghanistan     8425333.0        Asia      28.801   779.445314
# 1               Albania     1282697.0      Europe      55.230  1601.056136
# 2               Algeria     9279525.0      Africa      43.077  2449.008185
# 3                Angola     4232095.0      Africa      30.015  3520.610273
# 4             Argentina    17876956.0    Americas      62.485  5911.315053
# ..                  ...           ...         ...         ...          ...
# 138  West Bank and Gaza     1030585.0        Asia      43.160  1515.592329
# 139         Yemen, Rep.     4963829.0        Asia      32.548   781.717576
# 140              Zambia     2672000.0      Africa      42.038  1147.388831
# 141            Zimbabwe     3080907.0      Africa      48.451   406.884115
# 142            Zimbabwe     3080907.0      Africa      48.451   406.884115
#
#      population_y continent_y  life_exp_y     gdp_cap_y
# 0      31889923.0        Asia      43.828    974.580338
# 1       3600523.0      Europe      76.423   5937.029526
# 2      33333216.0      Africa      72.301   6223.367465
# 3      12420476.0      Africa      42.731   4797.231267
# 4      40301927.0    Americas      75.320  12779.379640
# ..            ...         ...         ...           ...
# 138     4018332.0        Asia      73.422   3025.349798
# 139    22211743.0        Asia      62.698   2280.769906
# 140    11746035.0      Africa      42.384   1271.211593
# 141    12311143.0      Africa      43.487    469.709298
# 142           NaN      Africa      43.487    469.709298
#
# [143 rows x 9 columns]

# %%
c_merge.head()
# Out:
#        country  year_x  population_x continent_x  life_exp_x    gdp_cap_x  \
# 0  Afghanistan    1952     8425333.0        Asia      28.801   779.445314
# 1      Albania    1952     1282697.0      Europe      55.230  1601.056136
# 2      Algeria    1952     9279525.0      Africa      43.077  2449.008185
# 3       Angola    1952     4232095.0      Africa      30.015  3520.610273
# 4    Argentina    1952    17876956.0    Americas      62.485  5911.315053
#
#    year_y  population_y continent_y  life_exp_y     gdp_cap_y
# 0    2007    31889923.0        Asia      43.828    974.580338
# 1    2007     3600523.0      Europe      76.423   5937.029526
# 2    2007    33333216.0      Africa      72.301   6223.367465
# 3    2007    12420476.0      Africa      42.731   4797.231267
# 4    2007    40301927.0    Americas      75.320  12779.379640

# %%
c_merge.head(10)
# Out:
#        country  year_x  population_x continent_x  life_exp_x     gdp_cap_x  \
# 0  Afghanistan    1952     8425333.0        Asia      28.801    779.445314
# 1      Albania    1952     1282697.0      Europe      55.230   1601.056136
# 2      Algeria    1952     9279525.0      Africa      43.077   2449.008185
# 3       Angola    1952     4232095.0      Africa      30.015   3520.610273
# 4    Argentina    1952    17876956.0    Americas      62.485   5911.315053
# 5    Australia    1952     8691212.0     Oceania      69.120  10039.595640
# 6      Austria    1952     6927772.0      Europe      66.800   6137.076492
# 7      Bahrain    1952      120447.0        Asia      50.939   9867.084765
# 8   Bangladesh    1952    46886859.0        Asia      37.484    684.244172
# 9      Belgium    1952     8730405.0      Europe      68.000   8343.105127
#
#    year_y  population_y continent_y  life_exp_y     gdp_cap_y
# 0    2007    31889923.0        Asia      43.828    974.580338
# 1    2007     3600523.0      Europe      76.423   5937.029526
# 2    2007    33333216.0      Africa      72.301   6223.367465
# 3    2007    12420476.0      Africa      42.731   4797.231267
# 4    2007    40301927.0    Americas      75.320  12779.379640
# 5    2007    20434176.0     Oceania      81.235  34435.367440
# 6    2007     8199783.0      Europe      79.829  36126.492700
# 7    2007      708573.0        Asia      75.635  29796.048340
# 8    2007   150448339.0        Asia      64.062   1391.253792
# 9    2007    10392226.0      Europe      79.441  33692.605080

# %%
c_merge.shape
# Out:
# (143, 11)

# %%
c_merge['population_growth'] = c_merge['population_y'] - c_merge['population_x']

# %%
c_merge.shape
# Out:
# (143, 12)

# %%
c_merge = c_merge.sort_values('population_growth', ascending=False).head(10)

# %%
c_merge = c_merge.reset_index()

# %%
c_merge = c_merge.drop(['index'], axis=1)

# %%
c_merge
# Out:
#          country  year_x  population_x continent_x  life_exp_x     gdp_cap_x  \
# 0          China    1952   556263527.0        Asia      44.000    400.448611
# 1          India    1952   372000000.0        Asia      37.373    546.565749
# 2  United States    1952   157553000.0    Americas      68.440  13990.482080
# 3      Indonesia    1952    82052000.0        Asia      37.468    749.681655
# 4         Brazil    1952    56602560.0    Americas      50.917   2108.944355
# 5       Pakistan    1952    41346560.0        Asia      43.436    684.597144
# 6     Bangladesh    1952    46886859.0        Asia      37.484    684.244172
# 7        Nigeria    1952    33119096.0      Africa      36.324   1077.281856
# 8         Mexico    1952    30144317.0    Americas      50.789   3478.125529
# 9    Philippines    1952    22438691.0        Asia      47.752   1272.880995
#
#    year_y  population_y continent_y  life_exp_y     gdp_cap_y  \
# 0    2007  1.318683e+09        Asia      72.961   4959.114854
# 1    2007  1.110396e+09        Asia      64.698   2452.210407
# 2    2007  3.011399e+08    Americas      78.242  42951.653090
# 3    2007  2.235470e+08        Asia      70.650   3540.651564
# 4    2007  1.900106e+08    Americas      72.390   9065.800825
# 5    2007  1.692706e+08        Asia      65.483   2605.947580
# 6    2007  1.504483e+08        Asia      64.062   1391.253792
# 7    2007  1.350312e+08      Africa      46.859   2013.977305
# 8    2007  1.087009e+08    Americas      76.195  11977.574960
# 9    2007  9.107729e+07        Asia      71.688   3190.481016
#
#    population_growth
# 0        762419569.0
# 1        738396331.0
# 2        143586947.0
# 3        141495000.0
# 4        133408087.0
# 5        127924057.0
# 6        103561480.0
# 7        101912068.0
# 8         78556574.0
# 9         68638596.0

# %%
names = ['China', 'India', 'United States', 'Indonesia', 'Brazil', 'Pakistan', 'Bangladesh', 'Nigeria', 'Mexico', 'Philippines']
pop_grow = (c_merge['population_growth'] / 10**6)

plt.figure(figsize=(15,9))
plt.bar(names,pop_grow,width=0.6)
plt.xlabel('Country')
plt.ylabel('Population Growth (Millions)')
plt.title('Top 10 Countries w/ the Biggest Population Growth (1952-2007)')
plt.xticks(rotation=45)

for x,y in zip(names, pop_grow):
    label = "{:.2f}".format(y)
    plt.annotate(label, 
                (x,y), 
                textcoords="offset points", 
                xytext=(0,10), 
                ha='center')
plt.show()
