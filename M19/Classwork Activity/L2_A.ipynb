# %%
# State and explain some of the examples of recommendation engines where they can be used?

# Social Media Sites recommend personalized videos and images based on your choice.
# E-Commerce sites recommend products to their users.
# Google Search can recommend and show personalized ads based on your choice.

# Write examples of Recommendation engines that can be used to make the user comfortable.
# Spotify recommend users music that they like.
# Youtube/Tiktok recommends videos to their users based on their past watch history.
# Instagram/Facebook recommends blogs/articles to their users based on their interests.
# GoogleTV recommends different channels to users based on their interests.
