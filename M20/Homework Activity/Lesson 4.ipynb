# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('Petrol Consumption.csv')

print(df.head())

y = df.pop('Petrol_Consumption')
x = df
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])

history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

model.summary()

y_pred = model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 569.0199 - mean_absolute_error: 569.0199 - val_loss: 615.6259 - val_mean_absolute_error: 615.6259
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 568.9678 - mean_absolute_error: 568.9678 - val_loss: 615.5873 - val_mean_absolute_error: 615.5873
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 568.9156 - mean_absolute_error: 568.9156 - val_loss: 615.5485 - val_mean_absolute_error: 615.5485
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 568.8634 - mean_absolute_error: 568.8634 - val_loss: 615.5090 - val_mean_absolute_error: 615.5090
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 568.8110 - mean_absolute_error: 568.8110 - val_loss: 615.4693 - val_mean_absolute_error: 615.4693
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 568.7586 - mean_absolute_error: 568.7586 - val_loss: 615.4296 - val_mean_absolute_error: 615.4296
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 568.7064 - mean_absolute_error: 568.7064 - val_loss: 615.3893 - val_mean_absolute_error: 615.3893
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 568.6541 - mean_absolute_error: 568.6541 - val_loss: 615.3490 - val_mean_absolute_error: 615.3490
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 568.6024 - mean_absolute_error: 568.6024 - val_loss: 615.3083 - val_mean_absolute_error: 615.3083
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 568.5507 - mean_absolute_error: 568.5507 - val_loss: 615.2670 - val_mean_absolute_error: 615.2670
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,301 (28.52 KB)
#  Trainable params: 2,433 (9.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 4,868 (19.02 KB)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Mean Absolute Error: 568.7769775390625
